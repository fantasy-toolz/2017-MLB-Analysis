# %% [markdown]
# # Matchup Analysis
#
# ### MSP 7.1.2017
#
# It's time. Fivethirtyeight has their model, we need one of our own.
#
# This model will update daily.

# %%
from IPython.display import HTML
HTML('''<script>code_show=true; function code_toggle() { if (code_show){ $('div.input').hide();} else { $('div.input').show(); } code_show = !code_show} $( document ).ready(code_toggle);</script><form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>code_show=true; function code_toggle() { if (code_show){ $('div.input').hide();} else { $('div.input').show(); } code_show = !code_show} $( document ).ready(code_toggle);</script><form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# boilerplate imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
# imports for scraping

from bs4 import BeautifulSoup

import requests

# %%
teams = ['angels','astros','athletics','bluejays','braves',\
        'brewers','cardinals','cubs','diamondbacks','dodgers',\
        'giants','indians','mariners','marlins','mets','nationals',\
        'orioles','padres','phillies','pirates','rangers',\
        'rays','redsox','rockies','royals','tigers','twins',\
        'whitesox','yankees']

# can go back seasons with ?season=2016 at end of url

# %%
# get twins data
#teams = ['twins']

Schedule = {}


for inteam in teams:
    
    print inteam+' ',
    
    Schedule[inteam] = {}
    
    r  = requests.get('http://www.fangraphs.com/teams/'+inteam+'/schedule')

    data = r.text

    soup = BeautifulSoup(data)

    table_div = soup.find('div' , {"class":"team-schedule-table"})
    table = table_div.find('table')

    # The first tr contains the field names.
    headings = [th.get_text() for th in table.find("tr").find_all("th")]

    # get number of games played
    ngames = 0
    for row in table.find_all("tr")[1:]:
        if [td.get_text() for td in row.find_all("td")][5] != '':
            ngames += 1       
        

    headings[3] = 'HomeWin'
    headings[5] = 'HomeRuns'
    headings[7] = 'HomeStarter'

    #print headings


    for indx,val in enumerate(headings):
        Schedule[inteam][val] = np.empty(ngames,dtype='S20')

    game = 0
    for row in table.find_all("tr")[1:]:
        if [td.get_text() for td in row.find_all("td")][5] != '':
            for indx,val in enumerate(headings):
                Schedule[inteam][val][game] = [td.get_text().decode() for td in row.find_all("td")][indx]
            game += 1
# Out:
# angels  astros  athletics  bluejays  braves  brewers  cardinals  cubs  diamondbacks  dodgers  giants  indians  mariners  marlins  mets  nationals  orioles  padres  phillies  pirates  rangers  rays  redsox  rockies  royals  tigers  twins  whitesox  yankees

# %%
#for day in Schedule['twins']['Date']:
#    print day.split()
# Out:
# ['Apr', '3,', '20174/3']
# ['Apr', '5,', '20174/5']
# ['Apr', '6,', '20174/6']
# ['Apr', '7,', '20174/7']
# ['Apr', '8,', '20174/8']
# ['Apr', '9,', '20174/9']
# ['Apr', '11,', '20174/11']
# ['Apr', '12,', '20174/12']
# ['Apr', '13,', '20174/13']
# ['Apr', '14,', '20174/14']
# ['Apr', '15,', '20174/15']
# ['Apr', '16,', '20174/16']
# ['Apr', '17,', '20174/17']
# ['Apr', '18,', '20174/18']
# ['Apr', '20,', '20174/20']
# ['Apr', '21,', '20174/21']
# ['Apr', '22,', '20174/22']
# ['Apr', '23,', '20174/23']
# ['Apr', '24,', '20174/24']
# ['Apr', '25,', '20174/25']
# ['Apr', '26,', '20174/26']
# ['Apr', '28,', '20174/28']
# ['Apr', '30,', '20174/30']
# ['May', '2,', '20175/2']
# ['May', '3,', '20175/3']
# ['May', '4,', '20175/4']
# ['May', '5,', '20175/5']
# ['May', '6,', '20175/6']
# ['May', '7,', '20175/7']
# ['May', '9,', '20175/9']
# ['May', '11,', '20175/11']
# ['May', '12,', '20175/12']
# ['May', '13,', '20175/13']
# ['May', '14,', '20175/14']
# ['May', '16,', '20175/16']
# ['May', '18,', '20175/18']
# ['May', '18,', '20175/18']
# ['May', '19,', '20175/19']
# ['May', '21,', '20175/21']
# ['May', '21,', '20175/21']
# ['May', '22,', '20175/22']
# ['May', '23,', '20175/23']
# ['May', '24,', '20175/24']
# ['May', '26,', '20175/26']
# ['May', '27,', '20175/27']
# ['May', '28,', '20175/28']
# ['May', '29,', '20175/29']
# ['May', '30,', '20175/30']
# ['May', '31,', '20175/31']
# ['Jun', '1,', '20176/1']
# ['Jun', '2,', '20176/2']
# ['Jun', '3,', '20176/3']
# ['Jun', '4,', '20176/4']
# ['Jun', '6,', '20176/6']
# ['Jun', '7,', '20176/7']
# ['Jun', '8,', '20176/8']
# ['Jun', '9,', '20176/9']
# ['Jun', '10,', '20176/10']
# ['Jun', '11,', '20176/11']
# ['Jun', '12,', '20176/12']
# ['Jun', '13,', '20176/13']
# ['Jun', '14,', '20176/14']
# ['Jun', '15,', '20176/15']
# ['Jun', '16,', '20176/16']
# ['Jun', '17,', '20176/17']
# ['Jun', '17,', '20176/17']
# ['Jun', '18,', '20176/18']
# ['Jun', '20,', '20176/20']
# ['Jun', '21,', '20176/21']
# ['Jun', '22,', '20176/22']
# ['Jun', '23,', '20176/23']
# ['Jun', '24,', '20176/24']
# ['Jun', '25,', '20176/25']
# ['Jun', '26,', '20176/26']
# ['Jun', '27,', '20176/27']
# ['Jun', '28,', '20176/28']
# ['Jun', '29,', '20176/29']
# ['Jun', '30,', '20176/30']
# ['Jul', '1,', '20177/1']
# ['Jul', '1,', '20177/1']
# ['Jul', '2,', '20177/2']
# ['Jul', '3,', '20177/3']
# ['Jul', '4,', '20177/4']
# ['Jul', '5,', '20177/5']
# ['Jul', '6,', '20177/6']
# ['Jul', '7,', '20177/7']
# ['Jul', '8,', '20177/8']
# ['Jul', '9,', '20177/9']
# ['Jul', '14,', '20177/14']
# ['Jul', '15,', '20177/15']
# ['Jul', '16,', '20177/16']
# ['Jul', '17,', '20177/17']
# ['Jul', '18,', '20177/18']
# ['Jul', '19,', '20177/19']
# ['Jul', '21,', '20177/21']
# ['Jul', '22,', '20177/22']
# ['Jul', '23,', '20177/23']
# ['Jul', '24,', '20177/24']
# ['Jul', '25,', '20177/25']
# ['Jul', '26,', '20177/26']
# ['Jul', '28,', '20177/28']
# ['Jul', '29,', '20177/29']
# ['Jul', '30,', '20177/30']
# ['Aug', '1,', '20178/1']
# ['Aug', '2,', '20178/2']
# ['Aug', '3,', '20178/3']

# %% [markdown]
# What about checking over a specific date range to see how run differential is coming along?

# %%
overgames = -20
rdiff = {}
for inteam in teams:

    rdiff[inteam] = np.sum(Schedule[inteam]['HomeRuns'][overgames:-1].astype(float) - Schedule[inteam]['OppRuns'][overgames:-1].astype(float))

import operator
sorted_x = sorted(rdiff.items(), key=operator.itemgetter(1)) 

print 


for tupl in sorted_x[::-1]:

    print '{0:<12s} {1:>6.1f}'.format(tupl[0],tupl[1])
# Out:
# indians        32.0
# cardinals      31.0
# dodgers        23.0
# orioles        23.0
# redsox         22.0
# yankees        16.0
# marlins        12.0
# rockies        12.0
# cubs            9.0
# angels          9.0
# twins           5.0
# nationals       4.0
# diamondbacks    4.0
# giants          1.0
# royals          1.0
# mariners       -3.0
# astros         -6.0
# rangers        -6.0
# tigers         -9.0
# pirates       -10.0
# phillies      -11.0
# padres        -14.0
# mets          -14.0
# braves        -15.0
# bluejays      -15.0
# rays          -16.0
# athletics     -23.0
# brewers       -29.0
# whitesox      -30.0

# %%
rdiff = {}
for inteam in teams:

    rdiff[inteam] = np.sum(Schedule[inteam]['HomeRuns'].astype(float) - Schedule[inteam]['OppRuns'].astype(float))

import operator
sorted_x = sorted(rdiff.items(), key=operator.itemgetter(1)) 

#print 


for tupl in sorted_x[::-1]:

    print '{0:<12s} {1:>6.1f}'.format(tupl[0],tupl[1])
# Out:
# dodgers       187.0
# astros        161.0
# diamondbacks  117.0
# yankees       112.0
# nationals     108.0
# indians        99.0
# redsox         70.0
# rockies        47.0
# cubs           43.0
# brewers        24.0
# cardinals      23.0
# rays            8.0
# rangers         3.0
# mariners       -2.0
# angels        -10.0
# royals        -10.0
# marlins       -12.0
# tigers        -23.0
# pirates       -29.0
# mets          -47.0
# braves        -60.0
# orioles       -62.0
# twins         -75.0
# bluejays      -78.0
# whitesox      -79.0
# phillies      -86.0
# athletics     -94.0
# giants       -109.0
# padres       -133.0

# %%
fig = plt.figure(figsize=(5,3))

ax1 = fig.add_axes([0.15,0.15,0.7,0.7])
ax2 = fig.add_axes([0.9,0.15,0.02,0.7])


teams2 = ['yankees','redsox','orioles','rays','bluejays']

clrs = cm.gnuplot

for indx,inteam in enumerate(teams2):

    ax1.plot(np.cumsum(Schedule[inteam]['HomeRuns'].astype(float) - Schedule[inteam]['OppRuns'].astype(float)),color=cm.gnuplot(indx/float(len(teams2)-1.),1.))
    

    
cmap = cm.gnuplot
 
import matplotlib as mpl

norm = mpl.colors.BoundaryNorm(boundaries=np.linspace(0,1.,len(teams2)+1.), ncolors=256)
cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap,norm=norm)
cb1.set_label('Team',size=16)
cb1.set_ticks(np.linspace(0.,1.,len(teams2)+1.) + 0.5/(len(teams2)+1.))
cb1.set_ticklabels(teams2)


    
    
ax1.set_title('2017 Run Differential')
ax1.set_xlabel('Game Number',size=18)    
ax1.set_ylabel('Run Differential',size=18)

# %%
fig = plt.figure(figsize=(5,3))

ax1 = fig.add_axes([0.15,0.15,0.7,0.7])
ax2 = fig.add_axes([0.9,0.15,0.02,0.7])


teams2 = ['nationals','mets','phillies','pirates','braves']

clrs = cm.gnuplot

for indx,inteam in enumerate(teams2):

    ax1.plot(np.cumsum(Schedule[inteam]['HomeRuns'].astype(float) - Schedule[inteam]['OppRuns'].astype(float)),color=cm.gnuplot(indx/float(len(teams2)-1.),1.))
    
 
import matplotlib as mpl

norm = mpl.colors.BoundaryNorm(boundaries=np.linspace(0,1.,len(teams2)+1.), ncolors=256)
cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap,norm=norm)
cb1.set_label('Team',size=16)
cb1.set_ticks(np.linspace(0.,1.,len(teams2)+1.) + 0.5/(len(teams2)+1.))
cb1.set_ticklabels(teams2)


    
    
ax1.set_title('2017 Run Differential')
ax1.set_xlabel('Game Number',size=18)    
ax1.set_ylabel('Run Differential',size=18)

# %%
fig = plt.figure(figsize=(5,3))

ax1 = fig.add_axes([0.15,0.15,0.7,0.7])
ax2 = fig.add_axes([0.9,0.15,0.02,0.7])


teams2 = ['royals','twins','indians','whitesox','tigers']

clrs = cm.gnuplot

for indx,inteam in enumerate(teams2):

    ax1.plot(np.cumsum(Schedule[inteam]['HomeRuns'].astype(float) - Schedule[inteam]['OppRuns'].astype(float)),color=cm.gnuplot(indx/float(len(teams2)-1.),1.))
    
 
import matplotlib as mpl

norm = mpl.colors.BoundaryNorm(boundaries=np.linspace(0,1.,len(teams2)+1.), ncolors=256)
cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap,norm=norm)
cb1.set_label('Team',size=16)
cb1.set_ticks(np.linspace(0.,1.,len(teams2)+1.) + 0.5/(len(teams2)+1.))
cb1.set_ticklabels(teams2)


    
    
ax1.set_title('2017 Run Differential')
ax1.set_xlabel('Game Number',size=18)    
ax1.set_ylabel('Run Differential',size=18)

# %% [markdown]
# Quick thoughts (on 7/1/2017):
# 1. What's going on with the Orioles??
# 2. Padres look like they have a commanding lead on being bad.
# 3. Dodgers look very good on the top end.
# 4. Big nose-dive for the Rockies lately. Time to start against them away?

# %% [markdown]
# Quick thoughts on 8/5/2017:
# 1. After the Astros went on a tear, the Dodgers looked beatable, but now the Dodgers are back on top.
# 2. The Padres are still bad, but the Giants have been giving them a run for their money.

# %% [markdown]
# ### Goal: make a model for teams facing each other that can be built from.

# %% [markdown]
# ### Checkpoint: Examining starters
#
# What kind of a lead or deficit are starters leaving with?

# %%
    
teams2 = ['indians','royals','whitesox','tigers','twins']

GameLog = {}


for inteam in teams:

        print inteam,

        GameLog[inteam] = {}

        r  = requests.get('http://www.fangraphs.com/teams/'+inteam+'/schedule')

        data = r.text

        soup = BeautifulSoup(data)

        table_div = soup.find('div' , {"class":"team-schedule-table"})
        table = table_div.find('table')

        # The first tr contains the field names.
        headings = [th.get_text() for th in table.find("tr").find_all("th")]

        #print headings

        # get number of games played
        ngames = 0
        for row in table.find_all("tr")[1:]:
            if [td.get_text() for td in row.find_all("td")][5] != '':
                GameLog[inteam][ngames] = {}
                sav = [td.find('a') for td in row.find_all("td")][0]
                GameLog[inteam][ngames]['link'] = sav.get('href')[0:25]+'plays'+sav.get('href')[29:]
                GameLog[inteam][ngames]['oppo'] = [td.get_text() for td in row.find_all("td")][8]
                GameLog[inteam][ngames]['home'] = [td.get_text() for td in row.find_all("td")][7]
                GameLog[inteam][ngames]['date'] = [td.get_text() for td in row.find_all("td")][0]
                ngames += 1       



print GameLog.keys()
# Out:
# angels astros athletics bluejays braves brewers cardinals cubs diamondbacks dodgers giants indians mariners marlins mets nationals orioles padres phillies pirates rangers rays redsox rockies royals tigers twins whitesox yankees ['mets', 'rockies', 'pirates', 'marlins', 'redsox', 'royals', 'rays', 'indians', 'rangers', 'twins', 'brewers', 'orioles', 'angels', 'phillies', 'giants', 'bluejays', 'dodgers', 'astros', 'cardinals', 'cubs', 'diamondbacks', 'mariners', 'yankees', 'braves', 'tigers', 'athletics', 'whitesox', 'nationals', 'padres']

# %%
teams2 = ['mariners']

starter_off = {}
starter_def = {}


for inteam in teams2:
    
    print inteam

    starter_off[inteam] = np.zeros(len(GameLog[inteam].keys()))
    starter_def[inteam] = np.zeros(len(GameLog[inteam].keys()))



    
    for indx,key in enumerate(GameLog[inteam].keys()):
 
        print 'Game number: ',indx+1,
    
        r  = requests.get(GameLog[inteam][key]['link'])
    
        #print GameLog[key]['link']
        print GameLog[inteam][key]['oppo'],

        data = r.text
    
        soup = BeautifulSoup(data)

        table = soup.findAll('table')[8]
        # The first tr contains the field names.
        headings = [th.get_text() for th in table.find("tr").find_all("th")]

        #print headings
        # get number of games played
        #ngames = 0
        nruns_o = 0.
        nruns_d = 0.
        for row in table.find_all("tr")[1:]:
            if GameLog[inteam][key]['oppo'].split()[1] in [td.get_text() for td in row.find_all("td")][0]:
                up = int([td.get_text() for td in row.find_all("td")][13])
                #print ~int([td.get_text() for td in row.find_all("td")][13])
                breakscore = [td.get_text() for td in row.find_all("td")][5].split('-')
                #print [td.get_text() for td in row.find_all("td")][2],up,[td.get_text() for td in row.find_all("td")][0],breakscore[0],breakscore[1]
                
                if up:
                    tmpruns_o = float(breakscore[0])
                else:
                    tmpruns_o = float(breakscore[1])
                    
                nruns_o = np.max([nruns_o,tmpruns_o])
                
                
            if GameLog[inteam][key]['home'].split()[1] in [td.get_text() for td in row.find_all("td")][0]:
                up = int([td.get_text() for td in row.find_all("td")][13])
                #print ~int([td.get_text() for td in row.find_all("td")][13])
                breakscore = [td.get_text() for td in row.find_all("td")][5].split('-')
                #print [td.get_text() for td in row.find_all("td")][2],up,[td.get_text() for td in row.find_all("td")][0],breakscore[0],breakscore[1]
                
                if up:
                    tmpruns_d = float(breakscore[0])
                else:
                    tmpruns_d = float(breakscore[1])
                    
                nruns_d = np.max([nruns_d,tmpruns_d])
                
        print nruns_o,nruns_d
        
        starter_off[inteam][indx] = nruns_o # runs scored by team
        starter_def[inteam][indx] = nruns_d # runs scored against team
# Out:
# mariners
# Game number:  1 Dallas Keuchel 0.0 2.0
# Game number:  2 Lance McCullers 1.0 2.0
# Game number:  3 Charlie Morton 2.0 0.0
# Game number:  4 Joe Musgrove 1.0 2.0
# Game number:  5 Jesse Chavez 1.0 3.0
# Game number:  6 Ricky Nolasco 2.0 3.0
# Game number:  7 Matt Shoemaker 6.0 1.0
# Game number:  8 Charlie Morton 3.0 0.0
# Game number:  9 Joe Musgrove 3.0 2.0
# Game number:  10 Mike Fiers 5.0 4.0
# Game number:  11 Martin Perez 1.0 1.0
# Game number:  12 Andrew Cashner 2.0 0.0
# Game number:  13 Cole Hamels 4.0 6.0
# Game number:  14 Tom Koehler 5.0 0.0
# Game number:  15 Wei-Yin Chen 0.0 4.0
# Game number:  16 Edinson Volquez 4.0 4.0
# Game number:  17 Cesar Valdez 3.0 5.0
# Game number:  18 Sean Manaea 1.0 2.0
# Game number:  19 Jharel Cotton 2.0 4.0
# Game number:  20 Andrew Triggs 6.0 0.0
# Game number:  21 Jordan Zimmermann 5.0 4.0
# Game number:  22 Daniel Norris 3.0 0.0
# Game number:  23 Justin Verlander 1.0 1.0
# Game number:  24 Carlos Carrasco 3.0 1.0
# Game number:  25 Danny Salazar 3.0 4.0
# Game number:  26 Josh Tomlin 3.0 5.0
# Game number:  27 Matt Shoemaker 3.0 2.0
# Game number:  28 Ricky Nolasco 4.0 2.0
# Game number:  29 Alex Meyer 6.0 2.0
# Game number:  30 Yu Darvish 1.0 1.0
# Game number:  31 Martin Perez 1.0 1.0
# Game number:  32 Andrew Cashner 0.0 2.0
# Game number:  33 Jerad Eickhoff 5.0 6.0
# Game number:  34 Zach Eflin 3.0 3.0
# Game number:  35 Marco Estrada 2.0 6.0
# Game number:  36 Joe Biagini 0.0 3.0
# Game number:  37 Marcus Stroman 2.0 1.0
# Game number:  38 Aaron Sanchez 1.0 0.0
# Game number:  39 Sean Manaea 4.0 3.0
# Game number:  40 Andrew Triggs 1.0 4.0
# Game number:  41 Jesse Hahn 4.0 0.0
# Game number:  42 Dylan Covey 4.0 0.0
# Game number:  43 Jose Quintana 1.0 1.0
# Game number:  44 Mike Pelfrey 1.0 8.0
# Game number:  45 Derek Holland 1.0 6.0
# Game number:  46 Joe Ross 1.0 10.0
# Game number:  47 Tanner Roark 1.0 5.0
# Game number:  48 Gio Gonzalez 0.0 2.0
# Game number:  49 Eduardo Rodriguez 0.0 2.0
# Game number:  50 Brian Johnson 0.0 5.0
# Game number:  51 Rick Porcello 1.0 0.0
# Game number:  52 Tyler Chatwood 5.0 3.0
# Game number:  53 Tyler Anderson 6.0 2.0
# Game number:  54 Antonio Senzatela 4.0 0.0
# Game number:  55 Kyle Freeland 2.0 5.0
# Game number:  56 Jake Odorizzi 8.0 2.0
# Game number:  57 Alex Cobb 9.0 1.0
# Game number:  58 Erasmo Ramirez 4.0 1.0
# Game number:  59 Hector Santiago 5.0 3.0
# Game number:  60 Adalberto Mejia 3.0 5.0
# Game number:  61 Kyle Gibson 1.0 2.0
# Game number:  62 Joe Biagini 3.0 2.0
# Game number:  63 Marcus Stroman 2.0 2.0
# Game number:  64 J.A. Happ 0.0 4.0
# Game number:  65 Adalberto Mejia 7.0 3.0
# Game number:  66 Kyle Gibson 6.0 8.0
# Game number:  67 Ervin Santana 5.0 4.0
# Game number:  68 Jose Berrios 2.0 6.0
# Game number:  69 Tyson Ross 2.0 6.0
# Game number:  70 Martin Perez 4.0 5.0
# Game number:  71 Yu Darvish 5.0 2.0
# Game number:  72 Anibal Sanchez 2.0 2.0
# Game number:  73 Jordan Zimmermann 3.0 2.0
# Game number:  74 Justin Verlander 3.0 4.0
# Game number:  75 Daniel Norris 5.0 3.0
# Game number:  76 Joe Musgrove 9.0 3.0
# Game number:  77 Lance McCullers 0.0 2.0
# Game number:  78 Francis Martes 2.0 4.0
# Game number:  79 Aaron Nola 2.0 3.0
# Game number:  80 Mark Leiter 4.0 3.0
# Game number:  81 Parker Bridwell 5.0 0.0
# Game number:  82 Ricky Nolasco 0.0 2.0
# Game number:  83 Jesse Chavez 2.0 1.0

# %% [markdown]
# #### The American League Central

# %%
plt.figure(figsize=(5,3))


for inteam in teams2:

    print inteam,np.cumsum(starter_off[inteam]-starter_def[inteam])[-1]
    plt.plot(np.cumsum(starter_off[inteam]-starter_def[inteam]))

plt.title('2017 Starter Run Differential')
plt.xlabel('Game Number',size=18)    
plt.ylabel('Run Differential',size=18)
# Out:
# indians 13.0
# royals -16.0
# whitesox -19.0
# tigers 1.0
# twins -13.0

# %%
teams2 = ['mariners']
pname = 'Paxton'
pa_num = 0

for inteam in teams2:
    
    print inteam

    for indx,key in enumerate(GameLog[inteam].keys()):
 
        if pname in GameLog[inteam][key]['home']:
            print '\n\nDate: ',GameLog[inteam][key]['date'].split(',')[0]
    
        r  = requests.get(GameLog[inteam][key]['link'])
    
        #print GameLog[key]['link']
        #print GameLog[inteam][key]['oppo'],

        data = r.text
    
        soup = BeautifulSoup(data)

        table = soup.findAll('table')[8]

        headings = [th.get_text() for th in table.find("tr").find_all("th")]
        #print headings

        for row in table.find_all("tr")[1:]:
            if pname in [td.get_text() for td in row.find_all("td")][0]:
                
                if ('scored' in [td.get_text() for td in row.find_all("td")][6]) |\
                ('homered' in [td.get_text() for td in row.find_all("td")][6]):
                    print pa_num,[td.get_text() for td in row.find_all("td")][6]
                
                    pa_num += 1
# Out:
# mariners
#
#
# Date:  Apr 5
#
#
# Date:  Apr 10
#
#
# Date:  Apr 15
#
#
# Date:  Apr 20
# 0 Adam Rosales singled to right (Liner). Jaff Decker scored. Rajai Davis scored on error. Adam Rosales advanced to 2B. Error by Mitch Haniger.
# 1 Ryon Healy doubled to left (Liner). Adam Rosales scored.
# 2 Adam Rosales hit a sacrifice fly to center (Fliner (Fly)). Rajai Davis scored.
# 3 Ryon Healy singled to left (Liner). Jed Lowrie scored. Khris Davis advanced to 2B.
#
#
# Date:  Apr 26
#
#
# Date:  May 2
# 4 Cameron Maybin hit a ground rule double (Fliner (Liner)). Andrelton Simmons scored.
# 5 Jefry Marte hit a sacrifice fly to center (Fly). Mike Trout scored. Albert Pujols advanced to 2B.
#
#
# Date:  May 31
#
#
# Date:  Jun 6
# 6 Brian Dozier homered (Fly).
# 7 Max Kepler reached on fielder's choice to second (Grounder). Miguel Sano scored. Robbie Grossman out at second.
# 8 Joe Mauer singled to center (Liner). Byron Buxton scored. Brian Dozier advanced to 3B.
#
#
# Date:  Jun 11
# 9 Josh Donaldson homered (Fly). Kevin Pillar scored.
# 10 Josh Donaldson singled to right (Grounder). Kevin Pillar scored.
# 11 Kendrys Morales singled to left (Liner). Josh Donaldson scored. Jose Bautista advanced to 2B.
#
#
# Date:  Jun 16
# 12 Elvis Andrus doubled to left (Liner). Delino DeShields scored. Shin-Soo Choo advanced to 3B.
# 13 Adrian Beltre singled to right (Liner). Shin-Soo Choo scored. Elvis Andrus scored.
# 14 Jonathan Lucroy singled to left (Grounder). Adrian Beltre scored. Rougned Odor scored.
# 15 Robinson Chirinos homered (Fliner (Fly)).
#
#
# Date:  Jun 21
# 16 James McCann homered (Fly).
# 17 Justin Upton singled to center (Grounder). J.D. Martinez scored.
# 18 Justin Upton singled to left (Liner). Miguel Cabrera scored. J.D. Martinez scored.
#
#
# Date:  Jun 27
# 19 Ty Kelly hit a sacrifice fly to center (Fliner (Fly)). Maikel Franco scored. Cam Perkins advanced to 3B.
# 20 Daniel Nava hit a sacrifice fly to right (Fliner (Liner)). Cam Perkins scored. Cameron Rupp advanced to 2B on error. Error by Mitch Haniger.
# 21 Maikel Franco homered (Fly).
#
#
# Date:  Jul 2
# 22 Yunel Escobar singled to right (Fliner (Liner)). Kole Calhoun scored. Albert Pujols advanced to 3B.

# %%
teams2 = ['orioles']
pname = 'Britton'
pa_num = 0

for inteam in teams2:
    
    print inteam

    for indx,key in enumerate(GameLog[inteam].keys()):
 
        if pname in GameLog[inteam][key]['home']:
            print '\n\nDate: ',GameLog[inteam][key]['date'].split(',')[0]
    
        r  = requests.get(GameLog[inteam][key]['link'])
    
        #print GameLog[key]['link']
        #print GameLog[inteam][key]['oppo'],

        data = r.text
    
        soup = BeautifulSoup(data)

        table = soup.findAll('table')[8]

        headings = [th.get_text() for th in table.find("tr").find_all("th")]
        #print headings

        for row in table.find_all("tr")[1:]:
            if pname in [td.get_text() for td in row.find_all("td")][0]:
                
                #if ('scored' in [td.get_text() for td in row.find_all("td")][6]) |\
                #('homered' in [td.get_text() for td in row.find_all("td")][6]):
                    print pa_num,[td.get_text() for td in row.find_all("td")][6]
                
                    pa_num += 1
# Out:
# orioles
# 0 Darwin Barney struck out swinging.
# 1 Devon Travis singled to shortstop (Grounder).
# 2 Josh Donaldson singled to left (Grounder). Devon Travis advanced to 2B.
# 3 Jose Bautista grounded into a double play to third (Grounder). Josh Donaldson out at second.
# 4 Kendrys Morales grounded out to third (Grounder).
# 5 Troy Tulowitzki grounded out to shortstop (Grounder).
# 6 Russell Martin walked.
# 7 Steve Pearce singled to left (Liner). Russell Martin advanced to 2B.
# 8 Kevin Pillar grounded out to third (Grounder).
# 9 Jose Bautista singled to left (Fliner (Liner)).
# 10 Kendrys Morales singled to left (Grounder). Jose Bautista advanced to 2B.
# 11 Troy Tulowitzki struck out swinging.
# 12 Russell Martin walked. Jose Bautista advanced to 3B. Ryan Goins advanced to 2B.
# 13 Steve Pearce grounded into a double play to shortstop (Grounder). Russell Martin out at second.
# 14 Brett Gardner struck out looking.
# 15 Gary Sanchez grounded out to pitcher (Grounder).
# 16 Chris Carter grounded out to third (Grounder).
# 17 Brett Gardner grounded out to shortstop (Grounder).
# 18 Austin Romine struck out swinging.
# 19 Matt Holliday singled to third (Grounder).
# 20 Chris Carter flied out to center (Fly).
# 21 Kendrys Morales grounded out to shortstop (Grounder).
# 22 Troy Tulowitzki singled to left (Grounder).
# 23 Russell Martin walked. Troy Tulowitzki advanced to 2B.
# 24 Russell Martin advanced on a wild pitch to 2B.
# 25 Kevin Pillar grounded out to shortstop (Grounder).
# 26 Steve Pearce flied out to center (Fliner (Fly)).
# 27 Russell Martin singled to left (Grounder).
# 28 Justin Smoak flied out to right (Fliner (Liner)).
# 29 Jarrod Saltalamacchia struck out swinging.
# 30 Russell Martin advanced on defensive indifference to 2B.
# 31 Devon Travis singled to right (Fliner (Liner)). Russell Martin scored.
# 32 Kevin Pillar singled to center (Liner). Devon Travis advanced to 2B.
# 33 Steve Pearce struck out swinging.
# 34 Mitch Moreland singled to left (Liner).
# 35 Dustin Pedroia walked. Mitch Moreland advanced to 2B.
# 36 Jackie Bradley Jr. hit into a triple play to shortstop (Fly). Mitch Moreland out at third. Dustin Pedroia out at second.
# 37 Mitch Moreland grounded out to second (Grounder).
# 38 Josh Rutledge singled to center (Fliner (Liner)).
# 39 Jackie Bradley Jr. struck out swinging.
# 40 Josh Rutledge advanced on defensive indifference to 2B.
# 41 Christian Vazquez flied out to right (Fliner (Fly)).
# 42 Orlando Arcia grounded out to pitcher (Liner).
# 43 Hernan Perez singled to center (Grounder).
# 44 Jonathan Villar grounded out to third (Grounder). Hernan Perez advanced to 2B.
# 45 Eric Thames walked.
# 46 Hernan Perez advanced on a wild pitch to 3B. Eric Thames
# 47 Ryan Braun grounded out to third (Grounder).

# %%
teams2 = ['mariners']
pname = 'Zunino'
pa_num = 0

for inteam in teams2:
    
    print inteam

    for indx,key in enumerate(GameLog[inteam].keys()):
 
        if pname in GameLog[inteam][key]['home']:
            print '\n\nDate: ',GameLog[inteam][key]['date'].split(',')[0]
    
        r  = requests.get(GameLog[inteam][key]['link'])
    
        #print GameLog[key]['link']
        #print GameLog[inteam][key]['oppo'],

        data = r.text
    
        soup = BeautifulSoup(data)

        table = soup.findAll('table')[8]

        headings = [th.get_text() for th in table.find("tr").find_all("th")]
        #print headings

        for row in table.find_all("tr")[1:]:
            if pname in [td.get_text() for td in row.find_all("td")][1]:
                
                #if ('scored' in [td.get_text() for td in row.find_all("td")][6]) |\
                #('homered' in [td.get_text() for td in row.find_all("td")][6]):
                    print pa_num,[td.get_text() for td in row.find_all("td")][6]
                
                    pa_num += 1
# Out:
# mariners
# 0 Mike Zunino grounded out to second (Grounder).
# 1 Mike Zunino grounded out to shortstop (Grounder).
# 2 Mike Zunino grounded out to third (Grounder).
# 3 Mike Zunino struck out looking.
# 4 Mike Zunino grounded out to shortstop (Grounder).
# 5 Mike Zunino singled to shortstop (Grounder). Danny Valencia advanced to 2B.
# 6 Mike Zunino struck out swinging.
# 7 Mike Zunino doubled to center (Fliner (Fly)).
# 8 Mike Zunino grounded out to shortstop (Grounder).
# 9 Mike Zunino flied out to left (Fly).
# 10 Mike Zunino struck out swinging.
# 11 Mike Zunino flied out to center (Fly).
# 12 Mike Zunino struck out swinging.
# 13 Mike Zunino singled to left (Fliner (Liner)).
# 14 Mike Zunino struck out swinging.
# 15 Mike Zunino struck out swinging.
# 16 Mike Zunino flied out to third (Fly).
# 17 Mike Zunino flied out to pitcher (Fly).
# 18 Mike Zunino struck out swinging.
# 19 Mike Zunino singled to center (Grounder). Kyle Seager scored.
# 20 Mike Zunino struck out swinging.
# 21 Mike Zunino singled to left (Fliner (Liner)).
# 22 Mike Zunino flied out to right (Fliner (Fly)).
# 23 Mike Zunino walked.
# 24 Mike Zunino fouled out to catcher (Fly).
# 25 Mike Zunino struck out swinging.
# 26 Mike Zunino grounded out to third (Grounder).
# 27 Mike Zunino singled to second (Fliner (Fly)).
# 28 Mike Zunino flied out to center (Fly).
# 29 Mike Zunino struck out looking.
# 30 Mike Zunino struck out swinging.
# 31 Mike Zunino struck out swinging.
# 32 Mike Zunino doubled to left (Grounder).
# 33 Mike Zunino lined out to shortstop (Liner).
# 34 Mike Zunino struck out looking.
# 35 Mike Zunino flied out to shortstop (Fly).
# 36 Mike Zunino flied out to shortstop (Fly).
# 37 Mike Zunino flied out to center (Fly).
# 38 Mike Zunino hit a ground rule double (Fliner (Fly)).
# 39 Mike Zunino was hit by a pitch.
# 40 Mike Zunino struck out swinging.
# 41 Mike Zunino struck out swinging.
# 42 Mike Zunino struck out looking.
# 43 Mike Zunino doubled to left (Fliner (Liner)). Taylor Motter scored. Leonys Martin advanced to 3B.
# 44 Mike Zunino struck out swinging.
# 45 Mike Zunino flied out to right (Fly).
# 46 Mike Zunino walked.
# 47 Mike Zunino grounded out to pitcher (Grounder).
# 48 Mike Zunino flied out to center (Fly).
# 49 Mike Zunino struck out swinging.
# 50 Mike Zunino struck out swinging.
# 51 Mike Zunino singled to left (Grounder).
# 52 Mike Zunino struck out looking.
# 53 Mike Zunino lined out to first (Liner).
# 54 Mike Zunino flied out to second (Fly).
# 55 Mike Zunino grounded into a double play to third (Grounder). Guillermo Heredia out at second.
# 56 Mike Zunino struck out swinging.
# 57 Mike Zunino was hit by a pitch. Guillermo Heredia advanced to 2B.
# 58 Mike Zunino walked.
# 59 Mike Zunino walked.
# 60 Mike Zunino singled to left (Liner).
# 61 Mike Zunino flied out to center (Fly).
# 62 Mike Zunino struck out looking.
# 63 Mike Zunino struck out swinging.
# 64 Mike Zunino struck out looking.
# 65 Mike Zunino grounded out to pitcher (Grounder).
# 66 Mike Zunino struck out swinging.
# 67 Mike Zunino flied out to left (Fly).
# 68 Mike Zunino grounded out to pitcher (Grounder).
# 69 Mike Zunino grounded out to shortstop (Grounder).
# 70 Mike Zunino struck out swinging.
# 71 Mike Zunino walked.
# 72 Mike Zunino advanced on a wild pitch to 2B.
# 73 Mike Zunino struck out looking.
# 74 Mike Zunino flied out to center (Fly).
# 75 Mike Zunino doubled to left (Fliner (Liner)).
# 76 Mike Zunino struck out looking.
# 77 Mike Zunino walked. Guillermo Heredia advanced to 2B.
# 78 Mike Zunino struck out looking.
# 79 Mike Zunino struck out swinging.
# 80 Mike Zunino grounded into a double play to third (Grounder). Guillermo Heredia out at second.
# 81 Mike Zunino struck out swinging.
# 82 Mike Zunino homered (Fliner (Fly)).
# 83 Mike Zunino struck out swinging.
# 84 Mike Zunino reached on fielder's choice to third (Grounder). Guillermo Heredia out at second.
# 85 Mike Zunino grounded into a double play to shortstop (Grounder). Guillermo Heredia out at second.
# 86 Mike Zunino struck out swinging.
# 87 Mike Zunino struck out swinging.
# 88 Mike Zunino grounded into a double play to third (Grounder). Taylor Motter out at second.
# 89 Mike Zunino struck out swinging.
# 90 Mike Zunino struck out swinging.
# 91 Mike Zunino struck out looking.
# 92 Mike Zunino flied out to left (Fly).
# 93 Mike Zunino walked.
# 94 Mike Zunino struck out looking.
# 95 Mike Zunino struck out looking.
# 96 Mike Zunino flied out to center (Fly).
# 97 Mike Zunino struck out looking.
# 98 Mike Zunino doubled to left (Liner).
# 99 Mike Zunino walked. Danny Valencia advanced to 2B.
# 100 Mike Zunino struck out swinging.
# 101 Mike Zunino singled to left (Liner).
# 102 Jarrod Dyson advanced on a wild pitch to 2B.
# 103 Mike Zunino struck out swinging.
# 104 Mike Zunino doubled to left (Grounder). Guillermo Heredia scored on error. Mike Zunino advanced to 2B. Error by Ian Desmond.
# 105 Mike Zunino struck out swinging.
# 106 Mike Zunino singled to left (Liner). Guillermo Heredia advanced to 2B.
# 107 Mike Zunino flied out to shortstop (Fly).
# 108 Mike Zunino struck out swinging.
# 109 Mike Zunino doubled to left (Fliner (Liner)). Danny Valencia scored.
# 110 Mike Zunino out on a dropped third strike. Jarrod Dyson advanced to 3B.
# 111 Mike Zunino singled to left (Fliner (Liner)).
# 112 Jean Segura advanced on a wild pitch to 2B.
# 113 Mike Zunino flied out to second (Fly).
# 114 Mike Zunino struck out swinging.
# 115 Mike Zunino struck out swinging.
# 116 Mike Zunino hit a sacrifice fly to left (Fly). Taylor Motter scored. Jarrod Dyson advanced to 2B.
# 117 Mike Zunino doubled to center (Fliner (Liner)). Danny Valencia scored. Jarrod Dyson scored.
# 118 Mike Zunino singled to left (Liner). Danny Valencia scored. Taylor Motter advanced to 3B.
# 119 Mike Zunino homered (Fly). Danny Valencia scored. Taylor Motter scored. Jarrod Dyson scored.
# 120 Mike Zunino struck out swinging.
# 121 Mike Zunino flied out to right (Fliner (Fly)).
# 122 Mike Zunino singled to right (Grounder). Nelson Cruz scored. Danny Valencia scored. Jarrod Dyson advanced to 3B.
# 123 Mike Zunino singled to center (Grounder). Jarrod Dyson advanced to 3B.
# 124 Mike Zunino struck out swinging.
# 125 Mike Zunino struck out swinging.
# 126 Mike Zunino singled to left (Grounder).
# 127 Mike Zunino struck out looking.
# 128 Mike Zunino struck out swinging.
# 129 Mike Zunino homered (Fly).
# 130 Mike Zunino walked.
# 131 Mike Zunino grounded out to third (Grounder).
# 132 Mike Zunino homered (Fly). Ben Gamel scored.
# 133 Mike Zunino flied out to right (Fliner (Liner)).
# 134 Mike Zunino struck out looking.
# 135 Mike Zunino walked.
# 136 Mike Zunino lined out to pitcher (Liner). Robinson Cano out at third.
# 137 Mike Zunino grounded out to second (Grounder).
# 138 Mike Zunino struck out swinging.
# 139 Mike Zunino walked. Danny Valencia advanced to 2B.
# 140 Mike Zunino struck out swinging.
# 141 Mike Zunino struck out looking.
# 142 Mike Zunino singled to right (Grounder).
# 143 Mike Zunino flied out to right (Fly).
# 144 Mike Zunino struck out swinging.
# 145 Mike Zunino lined out to third (Fliner (Liner)).
# 146 Mike Zunino singled to left (Liner).
# 147 Mike Zunino singled to center (Grounder). Kyle Seager scored. Danny Valencia advanced to 3B.
# 148 Mike Zunino struck out looking.
# 149 Mike Zunino homered (Fly).
# 150 Mike Zunino singled to center (Liner).
# 151 Mike Zunino doubled to center (Fliner (Liner)). Jarrod Dyson scored.
# 152 Mike Zunino lined out to third (Liner).
# 153 Mike Zunino flied out to center (Fly).
# 154 Mike Zunino struck out swinging.
# 155 Mike Zunino homered (Fliner (Fly)). Danny Valencia scored. Jarrod Dyson scored.
# 156 Mike Zunino was hit by a pitch.
# 157 Mike Zunino struck out swinging.
# 158 Mike Zunino flied out to right (Fliner (Liner)).
# 159 Mike Zunino struck out swinging.
# 160 Mike Zunino singled to center (Fliner (Fly)).
# 161 Mike Zunino struck out swinging.
# 162 Mike Zunino singled to right (Fliner (Liner)).
# 163 Mike Zunino struck out swinging.
# 164 Mike Zunino grounded out to third (Grounder).
# 165 Mike Zunino homered (Fly). Nelson Cruz scored. Danny Valencia scored.
# 166 Mike Zunino struck out swinging.
# 167 Mike Zunino was hit by a pitch. Kyle Seager advanced to 3B. Danny Valencia advanced to 2B.
# 168 Mike Zunino struck out looking.
# 169 Mike Zunino homered (Fliner (Fly)). Jarrod Dyson scored.
# 170 Mike Zunino homered (Fliner (Fly)). Jarrod Dyson scored.
# 171 Mike Zunino flied out to left (Fly).
# 172 Mike Zunino struck out swinging.
# 173 Mike Zunino struck out looking.
# 174 Mike Zunino singled to center (Grounder).
# 175 Mike Zunino struck out swinging.
# 176 Mike Zunino walked. Jarrod Dyson advanced to 2B.
# 177 Mike Zunino struck out swinging.
# 178 Mike Zunino fouled out to catcher (Fly).
# 179 Mike Zunino struck out looking.
# 180 Mike Zunino struck out swinging.
# 181 Mike Zunino flied out to shortstop (Fly).
# 182 Mike Zunino struck out swinging.
# 183 Mike Zunino homered (Fly). Mitch Haniger scored. Danny Valencia scored.
# 184 Mike Zunino doubled to left (Liner).
# 185 Mike Zunino advanced on a wild pitch to 3B.
# 186 Mike Zunino flied out to first (Fly).
# 187 Mike Zunino walked. Nelson Cruz scored. Mitch Haniger advanced to 3B. Jarrod Dyson advanced to 2B.
# 188 Mike Zunino struck out swinging.
# 189 Mike Zunino struck out swinging.
# 190 Mike Zunino grounded out to pitcher (Grounder).
# 191 Mike Zunino struck out looking.
# 192 Mike Zunino flied out to shortstop (Fly).
# 193 Mike Zunino walked.
# 194 Mike Zunino struck out swinging.
# 195 Mike Zunino grounded out to third (Grounder).
# 196 Mike Zunino flied out to left (Fly).
# 197 Mike Zunino walked.
# 198 Mike Zunino picked off.
# 199 Mike Zunino struck out looking.
# 200 Mike Zunino homered (Fly).
# 201 Mike Zunino grounded out to shortstop (Grounder).
# 202 Mike Zunino grounded out to third (Grounder).
# 203 Mike Zunino lined out to third (Liner).
# 204 Mike Zunino struck out looking.
# 205 Mike Zunino struck out looking.
# 206 Mike Zunino struck out swinging.
# 207 Mike Zunino fouled out to first (Fly).
# 208 Mike Zunino struck out swinging.
# 209 Mike Zunino flied out to center (Fliner (Fly)).
# 210 Mike Zunino struck out swinging.
# 211 Mike Zunino singled to right (Fliner (Liner)).
# 212 Mike Zunino flied out to second (Fly).
# 213 Mike Zunino homered (Fly).
# 214 Mike Zunino struck out swinging.
# 215 Mike Zunino flied out to right (Fly).
# 216 Mike Zunino flied out to left (Fly).
