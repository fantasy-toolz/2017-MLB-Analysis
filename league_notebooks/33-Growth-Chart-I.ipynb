# %% [markdown]
# # First Applications of Growth Chart Scraping
#
# ### MSP 10.16.2017
#
# Use the hard-fought data from growth chart construction.

# %%
from IPython.display import HTML
HTML('''<script>code_show=true; function code_toggle() { if (code_show){ $('div.input').hide();} else { $('div.input').show(); } code_show = !code_show} $( document ).ready(code_toggle);</script><form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
# boilerplate imports

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
# %matplotlib inline

# imports for scraping

from bs4 import BeautifulSoup
import requests

# %%
f = open('data/gamelogs.dat')



DDStats = {}

for line in f:
    q = [d.strip(" ") for d in line.split(';')]
    
    if q[0] not in DDStats.keys():
        DDStats[q[0]] = {}
        
    if q[1] not in DDStats[q[0]].keys():
        DDStats[q[0]][q[1]] = np.zeros(len(q)-3)
        
    for indx in range(0,len(q)-3):
        DDStats[q[0]][q[1]][indx] = float(q[indx+2])
    


f.close()


print(DDStats.keys())
# Out:
# ['PA', 'BB', 'HR', 'H', 'R', 'SO', 'RBI', 'SB']

# %% [markdown]
# #### Example Plot
#
# Check out a player's stats in context.

# %%
PAlist = np.zeros([len(np.array(DDStats['PA'].keys())),len(np.array(DDStats['PA']['Joey Votto']))])


stat = 'RBI'
print(len(np.array(DDStats[stat].keys())) )

pa_thresh = []
pa_level = 400.

for indx,player in enumerate(DDStats[stat].keys()):
    PAlist[indx] = np.cumsum(DDStats[stat][player])
    if np.sum(DDStats['PA'][player]) > pa_level:
        pa_thresh.append(indx)

    
print len(pa_thresh)

fig = plt.figure(figsize=(5,2))
ax = fig.add_axes([0.18,0.22,0.6,0.7])
ax2 = fig.add_axes([0.81,0.22,0.02,0.7])

    
    
for perc in range(100,-10,-10):
    ax.plot(np.percentile(PAlist[pa_thresh],perc,axis=0),color=cm.gnuplot(float(perc/100.),1.))
    

   
avg_players = ['Jon Jay']
    
for x in avg_players:
    ax.plot(np.cumsum(DDStats[stat][x]),color='gray',lw=2.)

    
ax.set_ylabel('RBIs',size=18)
ax.set_xlabel('Gameday Number',size=18)
    
cmap = mpl.cm.gnuplot; norm = mpl.colors.Normalize(vmin=0, vmax=100)
cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap,norm=norm)
cb1.set_label('Percentile',size=18)
# Out:
# 956
# 214

# %% [markdown]
# ### Find the Average Players

# %%
PAlist = np.zeros([len(np.array(DDStats['PA'].keys())),len(np.array(DDStats['PA']['Joey Votto']))])


stat = 'RBI'
print(len(np.array(DDStats[stat].keys())) )

pa_thresh = []
pa_level = 400.

for indx,player in enumerate(DDStats[stat].keys()):
    PAlist[indx] = np.cumsum(DDStats[stat][player])
    if np.sum(DDStats['PA'][player]) > pa_level:
        pa_thresh.append(indx)

    
print len(pa_thresh)


fifty_line = np.percentile(PAlist[pa_thresh],perc,axis=0)

fig = plt.figure(figsize=(5,2))
ax = fig.add_axes([0.18,0.22,0.6,0.7])
ax2 = fig.add_axes([0.81,0.22,0.02,0.7])

    
    
ax.plot(fifty_line,color='black')

nonzero = np.where(fifty_line > 0.)[0]

for indx,val in enumerate(fifty_line[nonzero]):
    sat_player = np.where(np.abs(PAlist[pa_thresh][nonzero[indx]] - val) == np.min(np.abs(PAlist[pa_thresh][nonzero[indx]] - val)))[0]
    print (np.array(DDStats[stat].keys())[pa_thresh])[sat_player]
# Out:
# 956
# 214
# ['Aaron Altherr' 'Avisail Garcia']
# ['Rougned Odor' 'Keon Broxton' 'Matt Joyce' 'J.T. Realmuto' 'A.J. Pollock'
#  'Albert Pujols' 'Robbie Grossman' 'Edwin Encarnacion' 'Elvis Andrus'
#  'Josh Reddick' 'Hernan Perez' 'Eugenio Suarez' 'Mike Trout' 'Tim Beckham'
#  'Melky Cabrera' 'Miguel Cabrera' 'Logan Forsythe' 'J.D. Martinez'
#  'Michael Taylor' 'Delino DeShields']
# ['Zack Cozart' 'Mike Zunino' 'Freddie Freeman' 'Cesar Hernandez']
# ['Aaron Altherr' 'Avisail Garcia']
# ['Freddie Freeman']
# ['Tucker Barnhart' 'Tommy Joseph' 'Jose Reyes' 'Logan Morrison'
#  'Curtis Granderson' 'Willson Contreras' 'Carlos Beltran' 'Kevin Kiermaier'
#  'Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza'
#  'Austin Hedges' 'Buster Posey' 'Martin Maldonado' 'Yangervis Solarte'
#  'Jackie Bradley Jr.' 'Hunter Pence']
# ['Willson Contreras' 'Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips']
# ['Freddy Galvis' 'Tucker Barnhart' 'Tommy Joseph']
# ['Aaron Altherr']
# ['Aaron Altherr' 'Avisail Garcia' 'Nolan Arenado' 'Adam Jones'
#  'Luis Valbuena']
# ['Freddy Galvis' 'Tucker Barnhart' 'Tommy Joseph' 'Jose Reyes'
#  'Logan Morrison' 'Curtis Granderson' 'Willson Contreras' 'Carlos Beltran'
#  'Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor'
#  'Jose Peraza' 'Austin Hedges' 'Buster Posey']
# ['Avisail Garcia' 'Nolan Arenado' 'Adam Jones' 'Luis Valbuena']
# ['Gregory Polanco' 'Aaron Altherr' 'Avisail Garcia' 'Nolan Arenado'
#  'Adam Jones']
# ['Adam Jones' 'Luis Valbuena' 'Zack Cozart' 'Mike Zunino']
# ['Austin Hedges' 'Buster Posey' 'Martin Maldonado']
# ['Zack Cozart' 'Mike Zunino' 'Freddie Freeman' 'Cesar Hernandez']
# ['Jose Peraza' 'Austin Hedges' 'Buster Posey']
# ['Adam Jones' 'Luis Valbuena' 'Zack Cozart' 'Mike Zunino' 'Freddie Freeman'
#  'Cesar Hernandez' 'Cody Bellinger' 'Carlos Gomez' 'Freddy Galvis']
# ['Delino DeShields' 'Gregory Polanco' 'Aaron Altherr' 'Avisail Garcia'
#  'Nolan Arenado']
# ['Nolan Arenado' 'Adam Jones' 'Luis Valbuena']
# ['Cesar Hernandez' 'Cody Bellinger' 'Carlos Gomez' 'Freddy Galvis']
# ['Logan Morrison' 'Curtis Granderson' 'Willson Contreras' 'Carlos Beltran'
#  'Kevin Kiermaier' 'Brandon Phillips']
# ['Carlos Gomez']
# ['Willson Contreras']
# ['Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton'
#  'Chris Taylor' 'Jose Peraza']
# ['Mike Napoli']
# ['Buster Posey']
# ['Jackie Bradley Jr.' 'Hunter Pence']
# ['Austin Hedges' 'Buster Posey' 'Martin Maldonado' 'Yangervis Solarte'
#  'Jackie Bradley Jr.' 'Hunter Pence' 'Jason Castro' 'Yadier Molina'
#  'Jose Ramirez' 'Kolten Wong']
# ['Willson Contreras' 'Carlos Beltran']
# ['Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton']
# ['Neil Walker' 'Francisco Lindor']
# ['Ian Happ' 'Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter'
#  'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera']
# ['Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter' 'Cory Spangenberg'
#  'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera' 'Mitch Haniger'
#  'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay'
#  'Ryan Goins' 'Mookie Betts' 'Kendrys Morales' 'Scooter Gennett'
#  'Dansby Swanson' 'Daniel Murphy' 'Bryce Harper' 'Ryan Braun']
# ['Freddie Freeman' 'Cesar Hernandez' 'Cody Bellinger' 'Carlos Gomez'
#  'Freddy Galvis' 'Tucker Barnhart']
# ['Willson Contreras' 'Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips'
#  'Giancarlo Stanton']
# ['Jason Castro' 'Yadier Molina' 'Jose Ramirez']
# ['Tommy Joseph' 'Jose Reyes' 'Logan Morrison']
# ['Carlos Gomez' 'Freddy Galvis' 'Tucker Barnhart' 'Tommy Joseph'
#  'Jose Reyes' 'Logan Morrison' 'Curtis Granderson' 'Willson Contreras'
#  'Carlos Beltran']
# ['Freddie Freeman' 'Cesar Hernandez']
# ['Tommy Joseph' 'Jose Reyes']
# ['Kolten Wong' 'Neil Walker' 'Francisco Lindor' 'Shin-Soo Choo']
# ['Willson Contreras' 'Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips'
#  'Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza' 'Austin Hedges'
#  'Buster Posey' 'Martin Maldonado' 'Yangervis Solarte' 'Jackie Bradley Jr.']
# ['Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza'
#  'Austin Hedges' 'Buster Posey' 'Martin Maldonado' 'Yangervis Solarte'
#  'Jackie Bradley Jr.' 'Hunter Pence' 'Jason Castro' 'Yadier Molina'
#  'Jose Ramirez' 'Kolten Wong' 'Neil Walker' 'Francisco Lindor'
#  'Shin-Soo Choo']
# ['Andrew Benintendi' 'Ryon Healy' 'Ian Happ' 'Brandon Crawford'
#  'Mitch Moreland']
# ['Carlos Gomez' 'Freddy Galvis' 'Tucker Barnhart' 'Tommy Joseph'
#  'Jose Reyes' 'Logan Morrison' 'Curtis Granderson' 'Willson Contreras'
#  'Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton'
#  'Chris Taylor' 'Jose Peraza' 'Austin Hedges' 'Buster Posey'
#  'Martin Maldonado' 'Yangervis Solarte']
# ['Austin Hedges' 'Buster Posey' 'Martin Maldonado' 'Yangervis Solarte'
#  'Jackie Bradley Jr.' 'Hunter Pence' 'Jason Castro']
# ['Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez']
# ['Willson Contreras' 'Carlos Beltran']
# ['Willson Contreras']
# ['Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay' 'Ryan Goins' 'Mookie Betts']
# ['Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera'
#  'Mitch Haniger' 'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez'
#  'Hanley Ramirez' 'Jon Jay']
# ['Matt Carpenter' 'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain'
#  'Odubel Herrera' 'Mitch Haniger' 'Nomar Mazara' 'Jose Altuve'
#  'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay' 'Ryan Goins']
# ['Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter']
# ['Hunter Pence' 'Jason Castro' 'Yadier Molina' 'Jose Ramirez']
# ['Yadier Molina' 'Jose Ramirez' 'Kolten Wong' 'Neil Walker'
#  'Francisco Lindor' 'Shin-Soo Choo' 'Scott Schebler' 'Eduardo Nunez'
#  'Brandon Belt' 'Mike Napoli' 'Justin Smoak']
# ['Logan Morrison']
# ['Jason Castro' 'Yadier Molina' 'Jose Ramirez' 'Kolten Wong' 'Neil Walker'
#  'Francisco Lindor' 'Shin-Soo Choo' 'Scott Schebler' 'Eduardo Nunez'
#  'Brandon Belt' 'Mike Napoli' 'Justin Smoak']
# ['Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera' 'Mitch Haniger'
#  'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay'
#  'Ryan Goins' 'Mookie Betts' 'Kendrys Morales' 'Scooter Gennett'
#  'Dansby Swanson' 'Daniel Murphy']
# ['Tommy Pham' 'Josh Harrison' 'Dustin Pedroia' 'Domingo Santana'
#  'Jonathan Villar' 'Justin Upton' 'Jose Bautista' 'Gary Sanchez'
#  'Ian Kinsler' 'Mark Reynolds' 'Manny Machado' 'Billy Hamilton'
#  'Starlin Castro' 'Yasiel Puig' 'Miguel Sano' 'Corey Seager' 'Ben Gamel'
#  'Justin Bour' 'Trea Turner' 'Jordy Mercer' 'Matt Davidson' 'Jorge Polanco'
#  'Whit Merrifield' 'Paul Goldschmidt' 'Jason Heyward' 'Alcides Escobar'
#  'Jose Iglesias' 'Derek Dietrich' 'Carlos Gonzalez' 'Carlos Correa'
#  'Javier Baez']
# ['Jason Castro' 'Yadier Molina' 'Jose Ramirez']
# ['Chris Taylor' 'Jose Peraza']
# ['Tommy Joseph']
# ['Curtis Granderson']
# ['Justin Smoak' 'Andrew Benintendi']
# ['Shin-Soo Choo' 'Scott Schebler' 'Eduardo Nunez' 'Brandon Belt']
# ['Scott Schebler' 'Eduardo Nunez' 'Brandon Belt' 'Mike Napoli'
#  'Justin Smoak' 'Andrew Benintendi' 'Ryon Healy' 'Ian Happ'
#  'Brandon Crawford']
# ['Carlos Beltran' 'Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton'
#  'Chris Taylor']
# ['Curtis Granderson' 'Willson Contreras' 'Carlos Beltran' 'Kevin Kiermaier'
#  'Brandon Phillips' 'Giancarlo Stanton']
# ['Brett Gardner' 'Justin Turner' 'Joey Gallo' 'Marcell Ozuna']
# ['Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza' 'Austin Hedges'
#  'Buster Posey']
# ['Jose Ramirez' 'Kolten Wong']
# ['Josh Harrison']
# ['Curtis Granderson']
# ['Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza']
# ['Ian Happ']
# ['Willson Contreras' 'Carlos Beltran']
# ['Yadier Molina' 'Jose Ramirez']
# ['Jose Reyes' 'Logan Morrison' 'Curtis Granderson']
# ['Bryce Harper' 'Ryan Braun' 'Didi Gregorius' 'Nick Markakis'
#  'Brett Gardner' 'Justin Turner' 'Joey Gallo']
# ['Lorenzo Cain' 'Odubel Herrera']
# ['Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor']
# ['Mitch Moreland' 'Matt Carpenter']
# ['Mike Moustakas' 'Anthony Rendon']
# ['Brandon Crawford']
# ['Carlos Beltran']
# ['Lorenzo Cain']
# ['Marwin Gonzalez' 'Hanley Ramirez']
# ['Didi Gregorius' 'Nick Markakis' 'Brett Gardner' 'Justin Turner'
#  'Joey Gallo' 'Marcell Ozuna' 'Kyle Schwarber' 'Randal Grichuk']
# ['Brandon Phillips' 'Giancarlo Stanton' 'Chris Taylor' 'Jose Peraza']
# ['Dansby Swanson' 'Daniel Murphy' 'Bryce Harper' 'Ryan Braun'
#  'Didi Gregorius' 'Nick Markakis' 'Brett Gardner' 'Justin Turner'
#  'Joey Gallo' 'Marcell Ozuna' 'Kyle Schwarber']
# ['Ryon Healy' 'Ian Happ' 'Brandon Crawford' 'Mitch Moreland']
# ['Yangervis Solarte' 'Jackie Bradley Jr.' 'Hunter Pence' 'Jason Castro']
# ['Logan Morrison']
# ['Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera'
#  'Mitch Haniger' 'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez'
#  'Hanley Ramirez' 'Jon Jay' 'Ryan Goins' 'Mookie Betts' 'Kendrys Morales'
#  'Scooter Gennett' 'Dansby Swanson' 'Daniel Murphy' 'Bryce Harper'
#  'Ryan Braun']
# ['Ian Kinsler' 'Mark Reynolds' 'Manny Machado' 'Billy Hamilton'
#  'Starlin Castro' 'Yasiel Puig' 'Miguel Sano']
# ['Matt Carpenter' 'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain'
#  'Odubel Herrera' 'Mitch Haniger' 'Nomar Mazara']
# ['Buster Posey' 'Martin Maldonado']
# ['Mitch Haniger' 'Nomar Mazara' 'Jose Altuve']
# ['Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera' 'Mitch Haniger'
#  'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay'
#  'Ryan Goins']
# ['Hunter Pence' 'Jason Castro']
# ['Brandon Belt' 'Mike Napoli' 'Justin Smoak']
# ['Jose Peraza' 'Austin Hedges' 'Buster Posey' 'Martin Maldonado'
#  'Yangervis Solarte']
# ['Ian Kinsler' 'Mark Reynolds' 'Manny Machado' 'Billy Hamilton'
#  'Starlin Castro' 'Yasiel Puig' 'Miguel Sano']
# ['Justin Turner' 'Joey Gallo' 'Marcell Ozuna' 'Kyle Schwarber'
#  'Randal Grichuk' 'Christian Yelich' 'Mike Moustakas' 'Anthony Rendon']
# ['Kolten Wong' 'Neil Walker' 'Francisco Lindor' 'Shin-Soo Choo'
#  'Scott Schebler' 'Eduardo Nunez' 'Brandon Belt']
# ['Martin Maldonado' 'Yangervis Solarte' 'Jackie Bradley Jr.' 'Hunter Pence']
# ['Ian Happ' 'Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter'
#  'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera'
#  'Mitch Haniger' 'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez'
#  'Hanley Ramirez' 'Jon Jay' 'Ryan Goins' 'Mookie Betts' 'Kendrys Morales'
#  'Scooter Gennett' 'Dansby Swanson' 'Daniel Murphy' 'Bryce Harper'
#  'Ryan Braun' 'Didi Gregorius' 'Nick Markakis' 'Brett Gardner'
#  'Justin Turner' 'Joey Gallo' 'Marcell Ozuna' 'Kyle Schwarber'
#  'Randal Grichuk' 'Christian Yelich' 'Mike Moustakas' 'Anthony Rendon'
#  'Tommy Pham' 'Josh Harrison' 'Dustin Pedroia' 'Domingo Santana'
#  'Jonathan Villar']
# ['Ryan Goins' 'Mookie Betts' 'Kendrys Morales' 'Scooter Gennett'
#  'Dansby Swanson' 'Daniel Murphy' 'Bryce Harper']
# ['Neil Walker' 'Francisco Lindor' 'Shin-Soo Choo' 'Scott Schebler'
#  'Eduardo Nunez' 'Brandon Belt']
# ['Nick Markakis' 'Brett Gardner' 'Justin Turner' 'Joey Gallo'
#  'Marcell Ozuna' 'Kyle Schwarber' 'Randal Grichuk' 'Christian Yelich'
#  'Mike Moustakas' 'Anthony Rendon' 'Tommy Pham' 'Josh Harrison'
#  'Dustin Pedroia' 'Domingo Santana' 'Jonathan Villar' 'Justin Upton']
# ['Ian Happ' 'Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter'
#  'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain']
# ['Nick Markakis' 'Brett Gardner' 'Justin Turner' 'Joey Gallo'
#  'Marcell Ozuna' 'Kyle Schwarber' 'Randal Grichuk' 'Christian Yelich'
#  'Mike Moustakas' 'Anthony Rendon' 'Tommy Pham']
# ['Brandon Belt' 'Mike Napoli' 'Justin Smoak' 'Andrew Benintendi']
# ['Jonathan Schoop' 'DJ LeMahieu' 'Nelson Cruz']
# ['Mookie Betts']
# ['Yonder Alonso' 'Jedd Gyorko' 'Alex Gordon']
# ['Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay']
# ['Jon Jay' 'Ryan Goins']
# ['Ryon Healy']
# ['Marcell Ozuna' 'Kyle Schwarber' 'Randal Grichuk' 'Christian Yelich'
#  'Mike Moustakas' 'Anthony Rendon']
# ['Jon Jay' 'Ryan Goins' 'Mookie Betts' 'Kendrys Morales']
# ['Brandon Phillips' 'Giancarlo Stanton']
# ['Scott Schebler' 'Eduardo Nunez' 'Brandon Belt' 'Mike Napoli']
# ['Mike Napoli' 'Justin Smoak' 'Andrew Benintendi' 'Ryon Healy']
# ['Hanley Ramirez' 'Jon Jay' 'Ryan Goins']
# ['Matt Carpenter' 'Cory Spangenberg' 'Manuel Margot']
# ['Kevin Kiermaier' 'Brandon Phillips' 'Giancarlo Stanton']
# ['Ian Happ' 'Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter'
#  'Cory Spangenberg' 'Manuel Margot' 'Lorenzo Cain' 'Odubel Herrera']
# ['Justin Smoak' 'Andrew Benintendi' 'Ryon Healy' 'Ian Happ'
#  'Brandon Crawford']
# ['Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay']
# ['Dansby Swanson' 'Daniel Murphy' 'Bryce Harper']
# ['Hanley Ramirez']
# ['Randal Grichuk' 'Christian Yelich' 'Mike Moustakas' 'Anthony Rendon'
#  'Tommy Pham']
# ['Justin Smoak' 'Andrew Benintendi' 'Ryon Healy' 'Ian Happ'
#  'Brandon Crawford' 'Mitch Moreland' 'Matt Carpenter' 'Cory Spangenberg'
#  'Manuel Margot' 'Lorenzo Cain']
# ['Jon Jay' 'Ryan Goins' 'Mookie Betts']
# ['Manny Machado' 'Billy Hamilton' 'Starlin Castro' 'Yasiel Puig'
#  'Miguel Sano' 'Corey Seager' 'Ben Gamel' 'Justin Bour' 'Trea Turner'
#  'Jordy Mercer' 'Matt Davidson' 'Jorge Polanco' 'Whit Merrifield'
#  'Paul Goldschmidt' 'Jason Heyward' 'Alcides Escobar' 'Jose Iglesias'
#  'Derek Dietrich' 'Carlos Gonzalez' 'Carlos Correa' 'Javier Baez'
#  'Maikel Franco' 'Ben Zobrist' 'David Peralta' 'Guillermo Heredia'
#  'Eric Hosmer' 'Matt Holliday' 'Travis Shaw' 'Robinson Cano']
# ['Maikel Franco' 'Ben Zobrist' 'David Peralta' 'Guillermo Heredia']
# ['Jon Jay' 'Ryan Goins' 'Mookie Betts' 'Kendrys Morales']
# ['Mitch Haniger' 'Nomar Mazara' 'Jose Altuve' 'Marwin Gonzalez'
#  'Hanley Ramirez' 'Jon Jay']
# ['Jose Altuve' 'Marwin Gonzalez' 'Hanley Ramirez' 'Jon Jay' 'Ryan Goins'
#  'Mookie Betts' 'Kendrys Morales' 'Scooter Gennett' 'Dansby Swanson'
#  'Daniel Murphy']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-856db5a280db> in <module>()
#      30
#      31 for indx,val in enumerate(fifty_line[nonzero]):
# ---> 32     sat_player = np.where(np.abs(PAlist[pa_thresh][nonzero[indx]] - val) == np.min(np.abs(PAlist[pa_thresh][nonzero[indx]] - val)))[0]
#      33     print (np.array(DDStats[stat].keys())[pa_thresh])[sat_player]
#
# IndexError: index 214 is out of bounds for axis 0 with size 214

# %% [markdown]
# Mr. Average Runs is Ryon Healy!
